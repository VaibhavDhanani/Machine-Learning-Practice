# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score,classification_report, precision_score, recall_score, f1_score
import lightgbm as lgb
from lightgbm import LGBMRegressor

# %%
data = pd.read_csv("../data/train.csv")
# data = data.dropna()
print("First few rows of the dataset:")
data.head()
# data.describe()
# data.info()
# Out:
# First few rows of the dataset:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
target_column = "SalePrice"
features = data.drop(columns=["PoolQC","Fence","MiscFeature","MasVnrType","Alley","FireplaceQu","Id","EnclosedPorch",
                             "3SsnPorch","ScreenPorch","PoolArea","MiscVal"])

numeric_features = features.select_dtypes(include=["int64","float64"]).columns
cat_features = features.select_dtypes(include=["object"]).columns

features[numeric_features] = features[numeric_features].fillna(features[numeric_features].mean())
features[cat_features] = features[cat_features].fillna(features[cat_features].mode())

target = data[target_column]
features = features.dropna()
# features.info()
features.head(50)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0           60       RL    65.000000     8450   Pave      Reg         Lvl
# 1           20       RL    80.000000     9600   Pave      Reg         Lvl
# 2           60       RL    68.000000    11250   Pave      IR1         Lvl
# 3           70       RL    60.000000     9550   Pave      IR1         Lvl
# 4           60       RL    84.000000    14260   Pave      IR1         Lvl
# 5           50       RL    85.000000    14115   Pave      IR1         Lvl
# 6           20       RL    75.000000    10084   Pave      Reg         Lvl
# 7           60       RL    70.049958    10382   Pave      IR1         Lvl
# 8           50       RM    51.000000     6120   Pave      Reg         Lvl
# 9          190       RL    50.000000     7420   Pave      Reg         Lvl
# 10          20       RL    70.000000    11200   Pave      Reg         Lvl
# 11          60       RL    85.000000    11924   Pave      IR1         Lvl
# 12          20       RL    70.049958    12968   Pave      IR2         Lvl
# 13          20       RL    91.000000    10652   Pave      IR1         Lvl
# 14          20       RL    70.049958    10920   Pave      IR1         Lvl
# 15          45       RM    51.000000     6120   Pave      Reg         Lvl
# 16          20       RL    70.049958    11241   Pave      IR1         Lvl
# 18          20       RL    66.000000    13695   Pave      Reg         Lvl
# 19          20       RL    70.000000     7560   Pave      Reg         Lvl
# 20          60       RL   101.000000    14215   Pave      IR1         Lvl
# 21          45       RM    57.000000     7449   Pave      Reg         Bnk
# 22          20       RL    75.000000     9742   Pave      Reg         Lvl
# 23         120       RM    44.000000     4224   Pave      Reg         Lvl
# 24          20       RL    70.049958     8246   Pave      IR1         Lvl
# 25          20       RL   110.000000    14230   Pave      Reg         Lvl
# 26          20       RL    60.000000     7200   Pave      Reg         Lvl
# 27          20       RL    98.000000    11478   Pave      Reg         Lvl
# 28          20       RL    47.000000    16321   Pave      IR1         Lvl
# 29          30       RM    60.000000     6324   Pave      IR1         Lvl
# 30          70  C (all)    50.000000     8500   Pave      Reg         Lvl
# 31          20       RL    70.049958     8544   Pave      IR1         Lvl
# 32          20       RL    85.000000    11049   Pave      Reg         Lvl
# 33          20       RL    70.000000    10552   Pave      IR1         Lvl
# 34         120       RL    60.000000     7313   Pave      Reg         Lvl
# 35          60       RL   108.000000    13418   Pave      Reg         Lvl
# 36          20       RL   112.000000    10859   Pave      Reg         Lvl
# 37          20       RL    74.000000     8532   Pave      Reg         Lvl
# 38          20       RL    68.000000     7922   Pave      Reg         Lvl
# 40          20       RL    84.000000     8658   Pave      Reg         Lvl
# 41          20       RL   115.000000    16905   Pave      Reg         Lvl
# 42          85       RL    70.049958     9180   Pave      IR1         Lvl
# 43          20       RL    70.049958     9200   Pave      IR1         Lvl
# 44          20       RL    70.000000     7945   Pave      Reg         Lvl
# 45         120       RL    61.000000     7658   Pave      Reg         Lvl
# 46          50       RL    48.000000    12822   Pave      IR1         Lvl
# 47          20       FV    84.000000    11096   Pave      Reg         Lvl
# 49          20       RL    66.000000     7742   Pave      Reg         Lvl
# 50          60       RL    70.049958    13869   Pave      IR2         Lvl
# 51          50       RM    52.000000     6240   Pave      Reg         Lvl
# 52          90       RM   110.000000     8472   Grvl      IR2         Bnk
#
#    Utilities LotConfig LandSlope  ... GarageQual GarageCond PavedDrive  \
# 0     AllPub    Inside       Gtl  ...         TA         TA          Y
# 1     AllPub       FR2       Gtl  ...         TA         TA          Y
# 2     AllPub    Inside       Gtl  ...         TA         TA          Y
# 3     AllPub    Corner       Gtl  ...         TA         TA          Y
# 4     AllPub       FR2       Gtl  ...         TA         TA          Y
# 5     AllPub    Inside       Gtl  ...         TA         TA          Y
# 6     AllPub    Inside       Gtl  ...         TA         TA          Y
# 7     AllPub    Corner       Gtl  ...         TA         TA          Y
# 8     AllPub    Inside       Gtl  ...         Fa         TA          Y
# 9     AllPub    Corner       Gtl  ...         Gd         TA          Y
# 10    AllPub    Inside       Gtl  ...         TA         TA          Y
# 11    AllPub    Inside       Gtl  ...         TA         TA          Y
# 12    AllPub    Inside       Gtl  ...         TA         TA          Y
# 13    AllPub    Inside       Gtl  ...         TA         TA          Y
# 14    AllPub    Corner       Gtl  ...         TA         TA          Y
# 15    AllPub    Corner       Gtl  ...         TA         TA          Y
# 16    AllPub   CulDSac       Gtl  ...         TA         TA          Y
# 18    AllPub    Inside       Gtl  ...         TA         TA          Y
# 19    AllPub    Inside       Gtl  ...         TA         TA          Y
# 20    AllPub    Corner       Gtl  ...         TA         TA          Y
# 21    AllPub    Inside       Gtl  ...         TA         TA          N
# 22    AllPub    Inside       Gtl  ...         TA         TA          Y
# 23    AllPub    Inside       Gtl  ...         TA         TA          Y
# 24    AllPub    Inside       Gtl  ...         TA         TA          Y
# 25    AllPub    Corner       Gtl  ...         TA         TA          Y
# 26    AllPub    Corner       Gtl  ...         TA         TA          Y
# 27    AllPub    Inside       Gtl  ...         TA         TA          Y
# 28    AllPub   CulDSac       Gtl  ...         TA         TA          Y
# 29    AllPub    Inside       Gtl  ...         Fa         TA          Y
# 30    AllPub    Inside       Gtl  ...         TA         Fa          N
# 31    AllPub   CulDSac       Gtl  ...         TA         TA          Y
# 32    AllPub    Corner       Gtl  ...         TA         TA          Y
# 33    AllPub    Inside       Gtl  ...         TA         TA          Y
# 34    AllPub    Inside       Gtl  ...         TA         TA          Y
# 35    AllPub    Inside       Gtl  ...         TA         TA          Y
# 36    AllPub    Corner       Gtl  ...         TA         TA          Y
# 37    AllPub    Inside       Gtl  ...         TA         TA          Y
# 38    AllPub    Inside       Gtl  ...         TA         TA          Y
# 40    AllPub    Inside       Gtl  ...         TA         TA          Y
# 41    AllPub    Inside       Gtl  ...         TA         TA          P
# 42    AllPub   CulDSac       Gtl  ...         TA         Gd          Y
# 43    AllPub   CulDSac       Gtl  ...         TA         TA          Y
# 44    AllPub    Inside       Gtl  ...         TA         TA          Y
# 45    AllPub    Inside       Gtl  ...         TA         TA          Y
# 46    AllPub   CulDSac       Gtl  ...         TA         TA          Y
# 47    AllPub    Inside       Gtl  ...         TA         TA          Y
# 49    AllPub    Inside       Gtl  ...         TA         TA          Y
# 50    AllPub    Corner       Gtl  ...         TA         TA          Y
# 51    AllPub    Inside       Gtl  ...         TA         TA          Y
# 52    AllPub    Corner       Mod  ...         TA         TA          Y
#
#    WoodDeckSF OpenPorchSF  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0           0          61       2    2008        WD         Normal    208500
# 1         298           0       5    2007        WD         Normal    181500
# 2           0          42       9    2008        WD         Normal    223500
# 3           0          35       2    2006        WD        Abnorml    140000
# 4         192          84      12    2008        WD         Normal    250000
# 5          40          30      10    2009        WD         Normal    143000
# 6         255          57       8    2007        WD         Normal    307000
# 7         235         204      11    2009        WD         Normal    200000
# 8          90           0       4    2008        WD        Abnorml    129900
# 9           0           4       1    2008        WD         Normal    118000
# 10          0           0       2    2008        WD         Normal    129500
# 11        147          21       7    2006       New        Partial    345000
# 12        140           0       9    2008        WD         Normal    144000
# 13        160          33       8    2007       New        Partial    279500
# 14          0         213       5    2008        WD         Normal    157000
# 15         48         112       7    2007        WD         Normal    132000
# 16          0           0       3    2010        WD         Normal    149000
# 18          0         102       6    2008        WD         Normal    159000
# 19          0           0       5    2009       COD        Abnorml    139000
# 20        240         154      11    2006       New        Partial    325300
# 21          0           0       6    2007        WD         Normal    139400
# 22        171         159       9    2008        WD         Normal    230000
# 23        100         110       6    2007        WD         Normal    129900
# 24        406          90       5    2010        WD         Normal    154000
# 25          0          56       7    2009        WD         Normal    256300
# 26        222          32       5    2010        WD         Normal    134800
# 27          0          50       5    2010        WD         Normal    306000
# 28        288         258      12    2006        WD         Normal    207500
# 29         49           0       5    2008        WD         Normal     68500
# 30          0          54       7    2008        WD         Normal     40000
# 31          0          65       6    2008        WD         Normal    149350
# 32          0          30       1    2008        WD         Normal    179900
# 33          0          38       4    2010        WD         Normal    165500
# 34        203          47       8    2007        WD         Normal    277500
# 35        113          32       9    2006        WD         Normal    309000
# 36        392          64       6    2009        WD         Normal    145000
# 37          0           0      10    2009        WD         Normal    153000
# 38          0          52       1    2010        WD        Abnorml    109000
# 40          0         138      12    2006        WD        Abnorml    160000
# 41          0         104       7    2007        WD         Normal    170000
# 42        240           0      12    2007        WD         Normal    144000
# 43        145           0       7    2008        WD         Normal    130250
# 44          0           0       5    2006        WD         Normal    141000
# 45        196          82       2    2010        WD         Normal    319900
# 46        168          43       8    2009        WD        Abnorml    239686
# 47          0         146       7    2007        WD         Normal    249700
# 49          0           0       1    2007        WD         Normal    127000
# 50          0          75       7    2007        WD         Normal    177000
# 51        112           0       9    2006        WD         Normal    114500
# 52        106           0       5    2010        WD         Normal    110000
#
# [50 rows x 69 columns]

# %%
# Converting Categorical Values

features[['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 
              'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 
              'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 
              'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 
              'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 
              'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 
              'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 
              'GarageCond', 'PavedDrive', 'SaleType', 
              'SaleCondition']] = features[['MSZoning', 'Street', 'LotShape', 
                                                'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 
                                                'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 
                                                'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 
                                                'Exterior2nd', 'ExterQual', 'ExterCond', 
                                                'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
                                                'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 
                                                'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 
                                                'GarageType', 'GarageFinish', 'GarageQual', 
                                                'GarageCond', 'PavedDrive', 
                                                'SaleType', 'SaleCondition']].apply(LabelEncoder().fit_transform)
target = features[target_column]
features.head(50)
features.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 69, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42
)
model = LGBMRegressor()
model.fit(features,target)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000512 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3448
# [LightGBM] [Info] Number of data points in the train set: 1346, number of used features: 65
# [LightGBM] [Info] Start training from score 187057.309807
# LGBMRegressor()

# %%
y_pred = model.predict(X_test)

# %%
# Step 6: Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared Score: {r2:.2f}")

# Display a sample of predictions
comparison = pd.DataFrame({"Actual": y_test, "Predicted": y_pred}).head(10)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')
report = classification_report(y_true, y_pred)

print("\nComparison of actual vs. predicted values:")
print(comparison)
print(report)
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Mean Squared Error: 13297709.96
# R-squared Score: 1.00
#
# Comparison of actual vs. predicted values:
#       Actual      Predicted
# 969   140000  139973.710043
# 1240  224900  224410.242735
# 369   162000  161987.112910
# 753   275500  276071.884941
# 303   149900  149905.565247
# 1222  143000  142981.761165
# 1004  181000  180899.919141
# 398    67000   68195.302587
# 1005  149900  149943.224158
# 80    193500  193637.156105
